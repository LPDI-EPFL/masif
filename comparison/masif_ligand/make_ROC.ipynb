# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ls
# Out:
# benchmark_set_full.txt        probis_fpr40.npy
# benchmark_set.txt             probis_fpr50.npy
# copy_dataset.py               probis_tpr100.npy
# data/                         probis_tpr40.npy
# freyr_pred/                   probis_tpr50.npy
# info.json                     query.json
# kripo_fpr050.npy              roc_curve_masif_probis_all_pockets.png
# kripo_fpr100.npy              roc_curve_masif_probis_pocket_split.png
# kripo_tpr050.npy              roc_curve_masif_probis_similar_pockets.png
# kripo_tpr100.npy              ROCs_025split_noleg.pdf
# make_probis_srfs.py           ROCs_025split.pdf
# make_ROC.ipynb                ROCs_040split_noleg.pdf
# masif_distplot.png            ROCs_040split.pdf
# masif_fpr100.npy              ROCs_nosplit_noleg.pdf
# masif_fpr40.npy               ROCs_nosplit.pdf
# masif_fpr50.npy               run_all.sh*
# masif_tpr100.npy              run_probis.sh*
# masif_tpr40.npy               run_probis.slurm
# ...

# %%
masif_fpr100 = np.load('masif_fpr100.npy')
masif_tpr100 = np.load('masif_tpr100.npy')

probis_fpr100 = np.load('probis_fpr100.npy')
probis_tpr100 = np.load('probis_tpr100.npy')

kripo_fpr100 = np.load('kripo_fpr100.npy')
kripo_tpr100 = np.load('kripo_tpr100.npy')

# %%
plt.plot(masif_fpr100,masif_tpr100,label='MaSIF AUC=0.95');
plt.plot(probis_fpr100,probis_tpr100,label='ProBiS AUC=0.90');
plt.plot(kripo_fpr100,kripo_tpr100,label='Kripo AUC=0.93');
plt.legend(loc='lower right');
plt.savefig('ROCs_nosplit_leg.pdf',format='pdf')

# %%
pwd
# Out:
# '/home/epfl_lpdi/masif_paper_ligand/masif/comparison/masif_ligand'

# %%
masif_fpr050 = np.load('masif_fpr50.npy')
masif_tpr050 = np.load('masif_tpr50.npy')

probis_fpr050 = np.load('probis_fpr50.npy')
probis_tpr050 = np.load('probis_tpr50.npy')

kripo_fpr050 = np.load('kripo_fpr050.npy')
kripo_tpr050 = np.load('kripo_tpr050.npy')

# %%
plt.plot(masif_fpr050,masif_tpr050,label='MaSIF AUC=0.91');
plt.plot(probis_fpr050,probis_tpr050,label='ProBiS AUC=0.84');
plt.plot(kripo_fpr050,kripo_tpr050,label='Kripo AUC=0.89');
plt.legend(loc='lower right');
plt.savefig('ROCs_050split_leg.pdf',format='pdf')

# %%
masif_fpr025 = np.load('fpr_masif_struct_split025.npy')
masif_tpr025= np.load('tpr_masif_struct_split025.npy')

probis_fpr025 = np.load('fpr_probis_struct_split025.npy')
probis_tpr025 = np.load('tpr_probis_struct_split025.npy')

kripo_fpr025 = np.load('kripo_fpr025.npy')
kripo_tpr025 = np.load('kripo_tpr025.npy')

# %%
plt.plot(masif_fpr025,masif_tpr025,label='MaSIF AUC=0.89');
plt.plot(probis_fpr025,probis_tpr025,label='ProBiS AUC=0.51');
plt.plot(kripo_fpr025,kripo_tpr025,label='Kripo AUC=0.89');
#plt.legend(loc='lower right');
plt.savefig('ROCs_025split_noleg.pdf',format='pdf')
