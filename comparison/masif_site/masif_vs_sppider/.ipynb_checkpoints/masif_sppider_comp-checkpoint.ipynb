# %%
import pymesh

# %%
import numpy as np
import sys
sys.path.append("../../../source/")

# %%
surf_dir = '/Users/pablo/lpdi_fs/seeder/data/ppi_benchmark_iface_prediction/01-benchmark_surfaces/'
test_file = '/Users/pablo/lpdi_fs/seeder/data/ppi_benchmark_iface_prediction/08-train_monomer_classifier_fp/lists/testing_30pc_tm.txt'
model_dir = '/Users/pablo/lpdi_fs/seeder/data/ppi_benchmark_iface_prediction/08-train_monomer_classifier_fp/models/'
transient_interactions_file = '/home/gainza/lpdi_fs/seeder/data/ppi_benchmark_transient/00-lists/unique_list.txt'
epitopes_list = '/home/gainza/lpdi_fs/seeder/data/ppi_benchmark_transient/00-lists/proteinag_ab.txt'

# List of sppider_predictions
sppider_pred_dir = '/Users/pablo/Dropbox/PPI_design/notebooks/Fig1/sppider_comp/pred/'

# %%
# Plot the comparison for transient interactions, epitopes, and highly solvated interfaces 

transient_pdbs = set([''.join(x[0:4]) for x in open(transient_interactions_file).readlines()])

#epitope_pdbs = set([''.join(x[0:4]).upper() for x in open(epitopes_list).readlines()])

# %%
# To follow SPPIDER's implementation (as an approximation) we only label as interface those residues 
        # with points with more than 4% RSA change and at least 5A RSA change.
def is_res_iface(res_labels, vertex_areas):
    sum_iface_area = 0.0
    sum_total_res_area = 0.0

    for ix, label in enumerate(res_labels): 
        sum_total_res_area += vertex_areas[ix]
        if label > 0:
            sum_iface_area += vertex_areas[ix]

    if sum_iface_area > 5.0 and sum_iface_area/sum_total_res_area > 0.04:
        return True
    else:
        return False

# %%
def assign_labels_per_residue(atoms, residues, ground_truth_mesh):
    # For every residue, assign a label on whether it is interface or not, based on the buried surface.
    flann = pyflann.FLANN()
    at_coord = np.array([at.get_coord() for at in atoms]).astype(float)
    verts = ground_truth_mesh.vertices.astype(float)

    labels = ground_truth_mesh.get_attribute('vertex_iface')
    ground_truth_mesh.add_attribute("vertex_area")
    vertex_areas = ground_truth_mesh.get_attribute("vertex_area")

    # Compute the closest atom to each vertex in vertices
    r,d = flann.nn(at_coord, verts)
    d = np.sqrt(d)
    n= len(r)
    
    # For each residue, assign the ground truth
    res_labels = {}
    res_areas = {}
    for ix, v in enumerate(verts): 
        pred = labels[ix]
        try:
            res_id = atoms[r[ix]].get_parent().get_id()
        except:
            set_trace()
        if res_id not in res_labels:
            res_labels[res_id] = []
            res_areas[res_id] = []
        res_labels[res_id].append(pred)
        res_areas[res_id].append(vertex_areas[ix])
    res_labels_tmp = []
    for key in res_labels:
        # To follow SPPIDER's implementation (as an approximation) we only label as interface those residues 
        # with points with more than 4% RSA change and at least 5A RSA change.
        if is_res_iface(res_labels[key], res_areas[key]):
            res_labels[key] = 1.0
        else:
            res_labels[key] = 0.0
    return res_labels

# %%
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
# Compute the score of each predicted surface. 
from IPython.core.debugger import set_trace
from Bio.PDB import *
import pyflann
import sklearn.metrics
import os
def compute_roc_auc_sppider(pdbid):
    parser = PDBParser()
    struct = parser.get_structure(sppider_pred_dir+pdbid+'.pdb',sppider_pred_dir+pdbid+'.pdb')
    atoms = Selection.unfold_entities(struct, 'A')
    residues = Selection.unfold_entities(struct, 'R')
    at_coord = np.array([at.get_coord() for at in atoms]).astype(float)
    
    ground_truth_mesh = pymesh.load_mesh(surf_dir+pdbid+'.ply')


    flann = pyflann.FLANN()
    
    verts = ground_truth_mesh.vertices.astype(float)
    
    # Compute the closest atom to each vertex in vertices
    r,d = flann.nn(at_coord, verts)
    d = np.sqrt(d)
    #print(np.mean(d))
    n= len(r)
    
    # For each vertex, assign the predictions
    pred = np.zeros((n))
    labels = ground_truth_mesh.get_attribute('vertex_iface')
    
    labels_per_residue = assign_labels_per_residue(atoms, residues, ground_truth_mesh)
    
    res_pred = {}
    for res in residues:
        if 'CA' in res:
            res_pred[res.get_id()] = res['CA'].bfactor/100

    res_pred_y = []
    res_label_y = []
    for key in labels_per_residue:
        if key in res_pred and key in labels_per_residue:
            res_pred_y.append(res_pred[key])
            res_label_y.append(labels_per_residue[key])

    try:
        res_roc_auc = sklearn.metrics.roc_auc_score(res_label_y, res_pred_y)
    except:
        res_roc_auc = 0.5
    print('Per residue ROC AUC: {:.2f}'.format(res_roc_auc))
    
    for vi in range(n):
        pred[vi] = atoms[r[vi]].bfactor/100
        
    roc_auc = sklearn.metrics.roc_auc_score(labels, pred)
    print('{} Per point ROC AUC: {:.2f}'.format(pdbid, roc_auc))
    return labels, pred, res_label_y, res_pred_y, roc_auc, res_roc_auc
    
all_pred = []
all_labels = []

all_pred_res = []
all_labels_res = []

all_roc_auc_per_prot_sppider = []
all_res_roc_auc_per_prot_sppider = []

for fn in os.listdir(sppider_pred_dir):  
    pdbid = fn.split('.')[0]
    #print(pdbid)
    #try:
    l, p, res_l, res_p, roc_auc, res_roc_auc = compute_roc_auc_sppider(pdbid)
    #except:
    #    continue

    all_pred.append(p)
    all_labels.append(l)
    
    all_pred_res.append(res_p)
    all_labels_res.append(res_l)
    
    all_roc_auc_per_prot_sppider.append(roc_auc)
    all_res_roc_auc_per_prot_sppider.append(res_roc_auc)
    
print("Number of proteins: {}".format(len(all_pred)))

all_pred = np.concatenate(all_pred, axis=0)
all_labels = np.concatenate(all_labels, axis=0)

all_pred_by_point_sppider = all_pred.copy()
all_labels_by_point_sppider = all_labels.copy()

#print(metrics.roc_auc_score(all_my_labels_per_res, all_my_pred_per_res))

all_labels_res = np.concatenate(all_labels_res, axis=0)

all_pred_res = np.concatenate(all_pred_res, axis=0)


all_roc_auc = sklearn.metrics.roc_auc_score(all_labels, all_pred)
all_roc_auc_res = sklearn.metrics.roc_auc_score(all_labels_res, all_pred_res)



print('Global ROC AUC: {:.2f}'.format(all_roc_auc))
print('Global ROC AUC per residue: {:.2f}'.format(all_roc_auc_res))

print('Median ROC AUC per protein : {:.2f}'.format(np.median(all_roc_auc_per_prot_sppider)))
print('Median ROC AUC per residue per protein: {:.2f}'.format(np.median(all_res_roc_auc_per_prot_sppider)))

pos_label = np.where(all_labels_res == 1)[0]
pos = all_pred_res[pos_label]
neg_label = np.where(all_labels_res == 0)[0]
neg = all_pred_res[neg_label]
sns.distplot(pos, hist=True, color='r', kde_kws={"shade": True}, norm_hist=True)
sns.distplot(neg, hist=True, color='b', kde_kws={"shade": True}, norm_hist=True)
# Out:
# Per residue ROC AUC: 0.69
# 2PMS_A Per point ROC AUC: 0.60
# Per residue ROC AUC: 0.83
# 1ZHH_A Per point ROC AUC: 0.80
# Per residue ROC AUC: 0.39
# 3FHC_A Per point ROC AUC: 0.31
# Per residue ROC AUC: 0.82
# 1W1W_B Per point ROC AUC: 0.81
# Per residue ROC AUC: 0.69
# 3BH6_B Per point ROC AUC: 0.64
# Per residue ROC AUC: 0.33
# 2OOR_AB Per point ROC AUC: 0.56
# Per residue ROC AUC: 0.54
# 4V0O_F Per point ROC AUC: 0.45
# Per residue ROC AUC: 0.48
# 2C0L_A Per point ROC AUC: 0.47
# Per residue ROC AUC: 0.90
# 1WDW_H Per point ROC AUC: 0.82
# Per residue ROC AUC: 0.72
# 4HDO_A Per point ROC AUC: 0.70
# Per residue ROC AUC: 0.57
# 3QML_D Per point ROC AUC: 0.68
# Per residue ROC AUC: 0.67
# 4BKX_B Per point ROC AUC: 0.65
# Per residue ROC AUC: 0.41
# 3WN7_A Per point ROC AUC: 0.31
# Per residue ROC AUC: 0.69
# 3BP8_AB Per point ROC AUC: 0.45
# Per residue ROC AUC: 0.71
# 4C9B_B Per point ROC AUC: 0.71
# Per residue ROC AUC: 0.55
# 4DVG_B Per point ROC AUC: 0.56
# Per residue ROC AUC: 0.64
# 3ZWL_B Per point ROC AUC: 0.56
# Per residue ROC AUC: 0.65
# 4YC7_B Per point ROC AUC: 0.64
# Per residue ROC AUC: 0.70
# 1EWY_A Per point ROC AUC: 0.64
# Per residue ROC AUC: 0.78
# 2V3B_A Per point ROC AUC: 0.69
# Per residue ROC AUC: 0.63
# 3VV2_A Per point ROC AUC: 0.68
# Per residue ROC AUC: 0.76
# 1F6M_A Per point ROC AUC: 0.76
# Per residue ROC AUC: 0.87
# 3O5T_A Per point ROC AUC: 0.87
# Per residue ROC AUC: 0.54
# 2XWT_C Per point ROC AUC: 0.45
# Per residue ROC AUC: 0.73
# 1JTD_B Per point ROC AUC: 0.69
# Per residue ROC AUC: 0.60
# 4X33_B Per point ROC AUC: 0.57
# Per residue ROC AUC: 0.68
# 2MTA_HL Per point ROC AUC: 0.48
# Per residue ROC AUC: 0.41
# 3R9A_AC Per point ROC AUC: 0.52
# Per residue ROC AUC: 0.53
# 2Y5B_A Per point ROC AUC: 0.42
# Per residue ROC AUC: 0.47
# 2V9T_B Per point ROC AUC: 0.31
# Per residue ROC AUC: 0.78
# 2I3T_A Per point ROC AUC: 0.70
# Per residue ROC AUC: 0.48
# 1NCA_N Per point ROC AUC: 0.38
# Per residue ROC AUC: 0.56
# 1GP2_BG Per point ROC AUC: 0.45
# Per residue ROC AUC: 0.59
# 3RT0_A Per point ROC AUC: 0.58
# Per residue ROC AUC: 0.57
# 5J57_A Per point ROC AUC: 0.42
# Per residue ROC AUC: 0.44
# 2WUS_A Per point ROC AUC: 0.40
# Per residue ROC AUC: 0.71
# 3MCA_B Per point ROC AUC: 0.73
# Per residue ROC AUC: 0.73
# 3H6G_B Per point ROC AUC: 0.71
# Per residue ROC AUC: 0.93
# 4ETP_B Per point ROC AUC: 0.89
# Per residue ROC AUC: 0.68
# 4Y61_B Per point ROC AUC: 0.52
# Per residue ROC AUC: 0.60
# 1I2M_B Per point ROC AUC: 0.51
# Per residue ROC AUC: 0.42
# 1XG2_A Per point ROC AUC: 0.31
# Per residue ROC AUC: 0.58
# 3LVK_AC Per point ROC AUC: 0.49
# Per residue ROC AUC: 0.82
# 4ZGY_A Per point ROC AUC: 0.82
# Per residue ROC AUC: 0.85
# 4ETP_A Per point ROC AUC: 0.86
# Per residue ROC AUC: 0.63
# 2AYO_A Per point ROC AUC: 0.54
# Per residue ROC AUC: 0.68
# 4M0W_A Per point ROC AUC: 0.59
# Per residue ROC AUC: 0.47
# 3SJA_I Per point ROC AUC: 0.35
# Per residue ROC AUC: 0.57
# 2QXV_A Per point ROC AUC: 0.51
# Per residue ROC AUC: 0.50
# 4YEB_A Per point ROC AUC: 0.45
# Per residue ROC AUC: 0.39
# 5TIH_A Per point ROC AUC: 0.29
# Per residue ROC AUC: 0.78
# 4XL5_C Per point ROC AUC: 0.75
# Per residue ROC AUC: 0.81
# 2F4M_A Per point ROC AUC: 0.84
# Per residue ROC AUC: 0.77
# 3VYR_B Per point ROC AUC: 0.74
# Per residue ROC AUC: 0.68
# 4FZV_A Per point ROC AUC: 0.63
# Per residue ROC AUC: 0.66
# 3NVN_A Per point ROC AUC: 0.69
# Per residue ROC AUC: 0.64
# 4ZRJ_A Per point ROC AUC: 0.64
# Per residue ROC AUC: 0.59
# 1XQS_A Per point ROC AUC: 0.52
# Per residue ROC AUC: 0.73
# 4LVN_A Per point ROC AUC: 0.75
# Number of proteins: 59
# Global ROC AUC: 0.61
# Global ROC AUC per residue: 0.65
# Median ROC AUC per protein : 0.59
# Median ROC AUC per residue per protein: 0.65

# %%
# Compute the prediction per residue.
def compute_pred_labels_per_residue(myid, scores):
    # We use the same pdb that sppider predicted. 
    parser = PDBParser()
    struct = parser.get_structure(sppider_pred_dir+myid+'.pdb',sppider_pred_dir+myid+'.pdb')
    atoms = Selection.unfold_entities(struct, 'A')
    residues = Selection.unfold_entities(struct, 'R')
    
    ground_truth_mesh = pymesh.load_mesh(surf_dir+myid+'.ply')
    
    res_labels = assign_labels_per_residue(atoms, residues, ground_truth_mesh)
    
    # Now assign predictions to each vert    
    verts = ground_truth_mesh.vertices
    ground_truth_mesh.add_attribute("vertex_area")
    vertex_areas = ground_truth_mesh.get_attribute("vertex_area")
    
    at_coord = np.array([at.get_coord() for at in atoms]).astype(float)
    verts = ground_truth_mesh.vertices.astype(float)
    
    
    residues = [x for x in verts]
    flann = pyflann.FLANN()
    r,d = flann.nn(at_coord, verts)
    d = np.sqrt(d)
    n= len(r)
    
    # For each residue, assign the mean score. 
    res_scores = {}
    res_areas = {}
    for ix, v in enumerate(verts): 
        pred = scores[ix]
        res_id = atoms[r[ix]].get_parent().get_id()
        if res_id not in res_scores:
            res_scores[res_id] = []
            res_areas[res_id] = []
        res_scores[res_id].append(pred)
        res_areas[res_id].append(pred)
    print('Total number of residues {}'.format(len(res_scores.keys())))
    ignored_residues= 0
    not_ignored_residues = 0
    for key in res_scores:
        if is_res_iface(res_scores[key], res_areas[key]):
        #if np.mean(res_scores[key]) > 0:
            res_scores[key] =  np.max(res_scores[key])  
            not_ignored_residues +=1
#        res_labels[key] = np.rint(np.max(res_labels[key]))
        else:
            res_scores[key] = 0.0     
            ignored_residues += 1
    print('Ignored {} residues'.format(ignored_residues))
    print('Not ignored {} residues'.format(not_ignored_residues))
    pred_per_res = []
    labels_per_res = []
    for key in res_labels: 
        if key in res_scores and key in res_labels:
            pred_per_res.append(res_scores[key])
            labels_per_res.append(res_labels[key])

    
    return pred_per_res, labels_per_res

# %%
def compute_model_scores(model):
    all_my_scores = []
    all_my_labels = []
    all_my_auc_per_protein = {}
    all_my_auc_per_res = []
    all_my_names = []
    
    all_my_pred_per_res = []
    all_my_labels_per_res = []
    
    outdir = 'out_surf/'
    if not os.path.exists(outdir):
        os.mkdir(outdir)
    outdir = os.path.join(outdir, model)
    if not os.path.exists(outdir):
        os.mkdir(outdir)
        
    test_scores = np.load(model_dir+model+'/test_scores.npy')
    test_names = np.load(model_dir+model+'/test_names.npy')
    test_labels = np.load(model_dir+model+'/test_labels.npy')
    count = 0

    for ix, name in enumerate(test_names): 
        
        fields = name[0].split('_')
        mypdb = fields[0]
        mypdb = ''.join(name[0][0:4])
        if name[1] == 'p1':
            myid = '_'.join([fields[0], fields[1]])
        if name[1] == 'p2':
            myid = '_'.join([fields[0], fields[2]])
        # Ignore if it wasn't computed for SPPIDER.
        if not os.path.exists(sppider_pred_dir+myid+'.pdb'):
            continue
        all_my_scores = np.concatenate([all_my_scores, test_scores[ix]])
        all_my_labels = np.concatenate([all_my_labels, test_labels[ix]])
        names = np.array([myid]*len(test_scores[ix]))
        all_my_names = np.concatenate([all_my_names, names])

        scores = test_scores[ix]
        labels = test_labels[ix].astype('float32')
        
        auc = metrics.roc_auc_score(labels, scores)
        all_my_auc_per_protein[myid] = auc

        weights = labels*(len(labels)/np.sum(labels))
        
        count = count+1
            
        if mypdb in transient_pdbs:
            print('{} ROC AUC: {}'.format(myid, auc))
            surf_fn = os.path.join(surf_dir, myid+'.ply')
            out_fn = outdir+'/'+myid+'.ply'
            
            # Compute the prediction per residue.
            pred_per_res, labels_per_res = compute_pred_labels_per_residue(myid, scores)
            auc_per_res = metrics.roc_auc_score(labels_per_res, pred_per_res)
            all_my_auc_per_res.append(auc_per_res)
            
            all_my_pred_per_res.append(pred_per_res)
            all_my_labels_per_res.append(labels_per_res)
            print('{} ROC AUC per res: {}'.format(myid, auc_per_res))

            

            #mymesh = color_shape(surf_fn, scores, out_fn)
    print('Number of proteins: {}'.format(count))
    print('Median AUC per res: {}'.format(np.median(all_my_auc_per_res)))
            
    return all_my_scores, all_my_labels, all_my_auc_per_protein, \
                    all_my_names, \
                    all_my_labels_per_res, all_my_pred_per_res, \
                    all_my_auc_per_res

# %%
from sklearn import metrics
import os

all_scores = {}
all_names ={}
all_labels = {}
all_auc_per_protein_masif = {}
all_auc_per_protein_per_res_masif = {}

model = 'logit_all_feat_3l'
all_scores[model], all_labels[model], all_auc_per_protein_masif[model], \
    all_names[model], \
    all_my_labels_per_res, all_my_pred_per_res, \
    all_auc_per_protein_per_res_masif[model] = compute_model_scores(model)

all_scores_ours = all_scores[model].copy()
all_labels_ours= all_labels[model].copy()
all_my_labels_per_res = np.concatenate(all_my_labels_per_res, axis = 0)
all_my_pred_per_res = np.concatenate(all_my_pred_per_res, axis = 0)    

print('Number of proteins: {}'.format(len(all_acc_per_protein[model].keys())))
print('ROC AUC for all points : {:.3f}'.format(metrics.roc_auc_score(all_labels_ours, all_scores_ours)))
print('ROC AUC for all residues: {:.3f}'.format(metrics.roc_auc_score(all_my_labels_per_res, all_my_pred_per_res)))
print('Median AUC per protein at the residue level: {:.3f}'.format(np.median(all_auc_per_protein_per_res_masif[model])))
#print('Median AUC per protein at the point level: {:.3f}'.format(np.median(all_auc_per_protein_masif[model])))
# Out:
# 3VV2_A ROC AUC: 0.798002525434
# Total number of residues 228
# Ignored 53 residues
# Not ignored 175 residues
# 3VV2_A ROC AUC per res: 0.605128205128
# 4LVN_A ROC AUC: 0.87220171131
# Total number of residues 245
# Ignored 107 residues
# Not ignored 138 residues
# 4LVN_A ROC AUC per res: 0.802927681888
# 4ZGY_A ROC AUC: 0.872971657303
# Total number of residues 328
# Ignored 152 residues
# Not ignored 176 residues
# 4ZGY_A ROC AUC per res: 0.873621460507
# 3LVK_AC ROC AUC: 0.678963951054
# Total number of residues 301
# Ignored 135 residues
# Not ignored 166 residues
# 3LVK_AC ROC AUC per res: 0.706997863248
# 4ETP_B ROC AUC: 0.915438422065
# Total number of residues 253
# Ignored 74 residues
# Not ignored 179 residues
# 4ETP_B ROC AUC per res: 0.8977195371
# 4V0O_F ROC AUC: 0.855637382897
# Total number of residues 272
# Ignored 202 residues
# Not ignored 70 residues
# 4V0O_F ROC AUC per res: 0.77978372434
# 3ZWL_B ROC AUC: 0.821582787373
# Total number of residues 292
# Ignored 122 residues
# Not ignored 170 residues
# 3ZWL_B ROC AUC per res: 0.771136653895
# 4XL5_C ROC AUC: 0.94317883194
# Total number of residues 207
# Ignored 136 residues
# Not ignored 71 residues
# 4XL5_C ROC AUC per res: 0.946428571429
# 4M0W_A ROC AUC: 0.787261150408
# Total number of residues 271
# Ignored 98 residues
# Not ignored 173 residues
# 4M0W_A ROC AUC per res: 0.714743589744
# 1XG2_A ROC AUC: 0.65933771835
# Total number of residues 245
# Ignored 103 residues
# Not ignored 142 residues
# 1XG2_A ROC AUC per res: 0.620960884354
# 5TIH_A ROC AUC: 0.255698553278
# Total number of residues 283
# Ignored 135 residues
# Not ignored 148 residues
# 5TIH_A ROC AUC per res: 0.305243445693
# 4ZRJ_A ROC AUC: 0.92432193629
# Total number of residues 263
# Ignored 99 residues
# Not ignored 164 residues
# 4ZRJ_A ROC AUC per res: 0.899783549784
# 3RT0_A ROC AUC: 0.669761303104
# Total number of residues 263
# Ignored 77 residues
# Not ignored 186 residues
# 3RT0_A ROC AUC per res: 0.620567375887
# 2XWT_C ROC AUC: 0.797987801496
# Total number of residues 192
# Ignored 66 residues
# Not ignored 126 residues
# 2XWT_C ROC AUC per res: 0.780017528484
# 1EWY_A ROC AUC: 0.788997165131
# Total number of residues 259
# Ignored 139 residues
# Not ignored 120 residues
# 1EWY_A ROC AUC per res: 0.761863173217
# 3SJA_I ROC AUC: 0.214218500951
# Total number of residues 310
# Ignored 112 residues
# Not ignored 198 residues
# 3SJA_I ROC AUC per res: 0.216282894737
# 2I3T_A ROC AUC: 0.826901868728
# Total number of residues 284
# Ignored 127 residues
# Not ignored 157 residues
# 2I3T_A ROC AUC per res: 0.818148754319
# 4DVG_B ROC AUC: 0.825349344096
# Total number of residues 275
# Ignored 93 residues
# Not ignored 182 residues
# 4DVG_B ROC AUC per res: 0.7527605245
# 2QXV_A ROC AUC: 0.859100824326
# Total number of residues 284
# Ignored 93 residues
# Not ignored 191 residues
# 2QXV_A ROC AUC per res: 0.822136563877
# 4BKX_B ROC AUC: 0.716165038633
# Total number of residues 266
# Ignored 119 residues
# Not ignored 147 residues
# 4BKX_B ROC AUC per res: 0.609185222672
# 2MTA_HL ROC AUC: 0.897631433164
# Total number of residues 320
# Ignored 145 residues
# Not ignored 175 residues
# 2MTA_HL ROC AUC per res: 0.830022075055
# 4ETP_A ROC AUC: 0.967095598997
# Total number of residues 327
# Ignored 102 residues
# Not ignored 225 residues
# 4ETP_A ROC AUC per res: 0.968410090257
# 4HDO_A ROC AUC: 0.733689367538
# Total number of residues 283
# Ignored 108 residues
# Not ignored 175 residues
# 4HDO_A ROC AUC per res: 0.759812143576
# 2AYO_A ROC AUC: 0.841473990322
# Total number of residues 309
# Ignored 100 residues
# Not ignored 209 residues
# 2AYO_A ROC AUC per res: 0.729240887914
# 5J57_A ROC AUC: 0.287413574178
# Total number of residues 225
# Ignored 78 residues
# Not ignored 147 residues
# 5J57_A ROC AUC per res: 0.376564945227
# 3WN7_A ROC AUC: 0.496520030363
# Total number of residues 247
# Ignored 100 residues
# Not ignored 147 residues
# 3WN7_A ROC AUC per res: 0.439008480104
# 3NVN_A ROC AUC: 0.855945837848
# Total number of residues 339
# Ignored 170 residues
# Not ignored 169 residues
# 3NVN_A ROC AUC per res: 0.808533281734
# 1W1W_B ROC AUC: 0.841573025051
# Total number of residues 284
# Ignored 164 residues
# Not ignored 120 residues
# 1W1W_B ROC AUC per res: 0.771029715414
# 2V3B_A ROC AUC: 0.912373706743
# Total number of residues 335
# Ignored 155 residues
# Not ignored 180 residues
# 2V3B_A ROC AUC per res: 0.931623931624
# 2PMS_A ROC AUC: 0.740886866504
# Total number of residues 279
# Ignored 135 residues
# Not ignored 144 residues
# 2PMS_A ROC AUC per res: 0.705908289242
# 1JTD_B ROC AUC: 0.910502389576
# Total number of residues 236
# Ignored 119 residues
# Not ignored 117 residues
# 1JTD_B ROC AUC per res: 0.886813186813
# 3R9A_AC ROC AUC: 0.808548758014
# Total number of residues 288
# Ignored 85 residues
# Not ignored 203 residues
# 3R9A_AC ROC AUC per res: 0.811861743912
# 3FHC_A ROC AUC: 0.40790854363
# Total number of residues 327
# Ignored 114 residues
# Not ignored 213 residues
# 3FHC_A ROC AUC per res: 0.370805369128
# 3H6G_B ROC AUC: 0.916086052247
# Total number of residues 305
# Ignored 113 residues
# Not ignored 192 residues
# 3H6G_B ROC AUC per res: 0.907196969697
# 1F6M_A ROC AUC: 0.833651867633
# Total number of residues 279
# Ignored 105 residues
# Not ignored 174 residues
# 1F6M_A ROC AUC per res: 0.832049418605
# 2Y5B_A ROC AUC: 0.884039490871
# Total number of residues 268
# Ignored 144 residues
# Not ignored 124 residues
# 2Y5B_A ROC AUC per res: 0.8546733762
# 4C9B_B ROC AUC: 0.633258154212
# Total number of residues 236
# Ignored 59 residues
# Not ignored 177 residues
# 4C9B_B ROC AUC per res: 0.6005189153
# 2OOR_AB ROC AUC: 0.903898726115
# Total number of residues 318
# Ignored 81 residues
# Not ignored 237 residues
# 2OOR_AB ROC AUC per res: 0.877740616871
# 1XQS_A ROC AUC: 0.810996563574
# Total number of residues 216
# Ignored 101 residues
# Not ignored 115 residues
# 1XQS_A ROC AUC per res: 0.736328702335
# 3BH6_B ROC AUC: 0.832929258741
# Total number of residues 266
# Ignored 136 residues
# Not ignored 130 residues
# 3BH6_B ROC AUC per res: 0.799511854951
# 3VYR_B ROC AUC: 0.890022386908
# Total number of residues 297
# Ignored 129 residues
# Not ignored 168 residues
# 3VYR_B ROC AUC per res: 0.861549815498
# 1I2M_B ROC AUC: 0.645227809161
# Total number of residues 312
# Ignored 165 residues
# Not ignored 147 residues
# 1I2M_B ROC AUC per res: 0.613759889921
# 1WDW_H ROC AUC: 0.812033646602
# Total number of residues 302
# Ignored 138 residues
# Not ignored 164 residues
# 1WDW_H ROC AUC per res: 0.842754467754
# 2V9T_B ROC AUC: 0.933942951961
# Total number of residues 179
# Ignored 79 residues
# Not ignored 100 residues
# 2V9T_B ROC AUC per res: 0.829471733086
# 3MCA_B ROC AUC: 0.773647186147
# Total number of residues 306
# Ignored 90 residues
# Not ignored 216 residues
# 3MCA_B ROC AUC per res: 0.596275188276
# 2C0L_A ROC AUC: 0.732090856144
# Total number of residues 250
# Ignored 85 residues
# Not ignored 165 residues
# 2C0L_A ROC AUC per res: 0.628434065934
# 4Y61_B ROC AUC: 0.657522667006
# Total number of residues 204
# Ignored 62 residues
# Not ignored 142 residues
# 4Y61_B ROC AUC per res: 0.635304659498
# 2WUS_A ROC AUC: 0.72309158882
# Total number of residues 275
# Ignored 98 residues
# Not ignored 177 residues
# 2WUS_A ROC AUC per res: 0.610368956743
# 4YC7_B ROC AUC: 0.786077040483
# Total number of residues 244
# Ignored 101 residues
# Not ignored 143 residues
# 4YC7_B ROC AUC per res: 0.705188679245
# 4X33_B ROC AUC: 0.825225167007
# Total number of residues 287
# Ignored 119 residues
# Not ignored 168 residues
# 4X33_B ROC AUC per res: 0.792615868028
# 3QML_D ROC AUC: 0.409222962412
# Total number of residues 232
# Ignored 105 residues
# Not ignored 127 residues
# 3QML_D ROC AUC per res: 0.500600961538
# 2F4M_A ROC AUC: 0.93593613887
# Total number of residues 259
# Ignored 96 residues
# Not ignored 163 residues
# 2F4M_A ROC AUC per res: 0.950728862974
# 1GP2_BG ROC AUC: 0.940254469799
# Total number of residues 275
# Ignored 110 residues
# Not ignored 165 residues
# 1GP2_BG ROC AUC per res: 0.906917885264
# 1ZHH_A ROC AUC: 0.86754211839
# Total number of residues 286
# Ignored 119 residues
# Not ignored 167 residues
# 1ZHH_A ROC AUC per res: 0.827314814815
# 3BP8_AB ROC AUC: 0.686929404186
# Total number of residues 336
# Ignored 64 residues
# Not ignored 272 residues
# 3BP8_AB ROC AUC per res: 0.664392402729
# 1NCA_N ROC AUC: 0.514418401981
# Total number of residues 287
# Ignored 114 residues
# Not ignored 173 residues
# 1NCA_N ROC AUC per res: 0.546187363834
# 4YEB_A ROC AUC: 0.33170158136
# Total number of residues 207
# Ignored 109 residues
# Not ignored 98 residues
# 4YEB_A ROC AUC per res: 0.437827225131
# 3O5T_A ROC AUC: 0.717758221921
# Total number of residues 223
# Ignored 96 residues
# Not ignored 127 residues
# 3O5T_A ROC AUC per res: 0.707022834985
# 4FZV_A ROC AUC: 0.898418435845
# Total number of residues 302
# Ignored 108 residues
# Not ignored 194 residues
# 4FZV_A ROC AUC per res: 0.882090384973
# Number of proteins: 59
# Median AUC per res: 0.771029715414
# Number of proteins: 59
# ROC AUC for all points : 0.768
# ROC AUC for all residues: 0.727
# Median AUC per protein at the residue level: 0.771

# %%
all_auc_per_protein_masif_list = [all_auc_per_protein_masif[model][x] for x in all_auc_per_protein_masif[model].keys() ]
print(np.median(all_auc_per_protein_masif_list))
# Out:
# 0.812033646602

# %%
all_auc_per_protein_per_res_masif_list = [x for x in all_auc_per_protein_per_res_masif[model] ]
print(np.median(all_auc_per_protein_per_res_masif_list))
# Out:
# 0.771029715414

# %%
import seaborn as sns
sns.set(style="white", context="talk")

xdata = ['MaSIF-site', 'SPPIDER']
ydata = [np.median(all_auc_per_protein_per_res_masif_list), \
        np.median(all_res_roc_auc_per_prot_sppider) ]

f, (ax1) = plt.subplots(1, 1, figsize=(4, 4), sharex=False)

plt.ylim([0.5,1.0])

sns.barplot(x=xdata, y=ydata, ax=ax1, palette=['lightgray', 'blue'])

ax1.set_ylim([0.5,1])
ax1.set_xticks([])

ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
#axes[0].spines['right'].set_visible(False)
#axes[0].spines['top'].set_visible(False)


print(ydata)

plt.savefig('sppider_bars.pdf', type='pdf')
# Out:
# [0.77102971541431009, 0.64978040284719063]

# %%
# Plot per resdiue
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
#sns.set(style="white", context="talk")


pos_label = np.where(all_my_labels_per_res == 1)[0]
pos = all_my_pred_per_res[pos_label]
neg_label = np.where(all_my_labels_per_res == 0)[0]
neg = all_my_pred_per_res[neg_label]


f, ax = plt.subplots(1, 1, figsize=(8, 4), sharex=False)
sns.distplot(pos, hist=True, color='r', kde_kws={"shade": True},ax=ax,  norm_hist=True)
sns.distplot(neg, hist=True, color='b', kde_kws={"shade": True},ax=ax, norm_hist=True)
plt.xlim([0,1])
ax.set_xticks([])
ax.set_yticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
print(metrics.roc_auc_score(all_my_labels_per_res, all_my_pred_per_res))
#plt.savefig('dist_plot_ours.pdf', type='pdf')
# Out:
# 0.774402314753

# %%
# Plot per point
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
#sns.set(style="white", context="talk")


pos_label = np.where(all_labels_ours == 1)[0]
pos = all_scores_ours[pos_label]
neg_label = np.where(all_labels_ours == 0)[0]
neg = all_scores_ours[neg_label]


f, ax = plt.subplots(1, 1, figsize=(8, 4), sharex=False)
sns.distplot(pos, hist=True, color='r', kde_kws={"shade": True},ax=ax,  norm_hist=True)
sns.distplot(neg, hist=True, color='b', kde_kws={"shade": True},ax=ax, norm_hist=True)
plt.xlim([0,1])
ax.set_xticks([])
ax.set_yticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
print(metrics.roc_auc_score(all_labels_ours, all_scores_ours))
#plt.savefig('dist_plot_ours.pdf', type='pdf')
# Out:
# 0.768387398481

# %%
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
#sns.set(style="white", context="talk")


pos_label = np.where(all_labels_ours == 1)[0]
pos = all_scores_ours[pos_label]
neg_label = np.where(all_labels_ours == 0)[0]
neg = all_scores_ours[neg_label]


f, ax = plt.subplots(1, 1, figsize=(8, 4), sharex=False)
sns.distplot(pos, hist=True, color='r', kde_kws={"shade": True},ax=ax,  norm_hist=True)
sns.distplot(neg, hist=True, color='b', kde_kws={"shade": True},ax=ax, norm_hist=True)
plt.xlim([0,1])
ax.set_xticks([])
ax.set_yticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
print(metrics.roc_auc_score(all_my_labels_per_res, all_my_pred_per_res))
plt.savefig('dist_plot_ours.pdf', type='pdf')
# Out:
# 0.721038421405

# %%
pos_label = np.where(all_labels_by_point_sppider == 1)[0]
pos = all_pred_by_point_sppider[pos_label]
neg_label = np.where(all_labels_by_point_sppider == 0)[0]
neg = all_pred_by_point_sppider[neg_label]
f, ax = plt.subplots(1, 1, figsize=(8, 4), sharex=False)
sns.distplot(pos, hist=True, color='r', kde_kws={"shade": True},ax=ax,  norm_hist=True)
sns.distplot(neg, hist=True, color='b', kde_kws={"shade": True},ax=ax, norm_hist=True)
plt.xlim([0,1])
ax.set_xticks([])
ax.set_yticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
#axes[1].spines['top'].set_visible(False)
#axes[0].spines['right'].set_visible(False)
#axes[0].spines['top'].set_visible(False)
print(metrics.roc_auc_score(all_labels_by_point_sppider, all_pred_by_point_sppider))
plt.savefig('dist_plot_sppider.pdf', type='pdf')
# Out:
# 0.61029668819

# %%
np.sum(all_my_labels_per_res)

# %%
# Randomly select 8 transient pdbs. 
import os
rand_transient_pdbs = os.listdir(sppider_pred_dir)
np.random.shuffle(rand_transient_pdbs)
print(rand_transient_pdbs[0:8])

# %%
#### Hphobicity comparison
hphob_scores = np.load('/home/gainza/lpdi_fs/seeder/data/ppi_benchmark_iface_prediction/09-hphob_predictor/hphob_vals.npy')
iface_labels = np.load('/home/gainza/lpdi_fs/seeder/data/ppi_benchmark_iface_prediction/09-hphob_predictor/iface_labels.npy')

print(metrics.roc_auc_score(iface_labels, hphob_scores))
# Out:
# 0.615181488908

# %%
fpr, tpr, threshold = metrics.roc_curve(iface_labels, hphob_scores)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
sns.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-e4366518dfd9> in <module>()
#       4
#       5 plt.title('Receiver Operating Characteristic')
# ----> 6 sns.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
#       7 plt.legend(loc = 'lower right')
#       8 plt.plot([0, 1], [0, 1],'r--')
#
# AttributeError: 'module' object has no attribute 'plot'

# %%
print (threshold)
# Out:
# [ 5.5      4.5      4.49999 ..., -4.49998 -4.49999 -4.5    ]
